# %% [markdown]
# <h1 style='text-align:center; font-weight:bold'>
#     Fundamentos de Matplotlib
# </h1>

# %% [markdown]
# ## **Librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = False

# %%
from datetime import datetime, timedelta
import winsound

# %% [markdown]
# ## **Datos**

# %%
X = np.linspace(0, 5, 11)
y = X**2

# %% [markdown]
# ### **Gráfico sencillo**

# %%
fig, ax = plt.subplots(figsize=(12, 5))
fig.patch.set_facecolor('#21252b') 
ax.set_facecolor('#282c34') 

plt.suptitle('First Graph', color='w', weight=1000, fontsize=15)

plt.xlabel('Variable X', color='w', fontsize=13)
plt.ylabel('Variable Y', color='w', fontsize=13)

plt.xticks(fontsize=10, color='w', weight=1000)
plt.yticks(fontsize=10, color='w', weight=500)

plt.plot(X, y, marker='o')
plt.grid(linewidth=0.2)
plt.show()

# %% [markdown]
# ### **Gráficos multiples**

# %% [markdown]
# #### **2 Gráficos**

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
fig.patch.set_facecolor('#21252b') 

fig.suptitle('Gráficos multiples', fontsize=15, color='w', weight=1000)

# First chart
plt.subplot(1,2,1)
plt.plot(X,y)
# ax[0].set_facecolor('#282c34') 
plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

# Second chart
plt.subplot(1,2,2)
plt.scatter(X,y)
plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

for i in range(2):
    ax[i].set_facecolor('#282c34') 
    ax[i].grid(linewidth=0.2)

plt.show()

# %% [markdown]
# #### **Más de 2 Gráficos**

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 7))
fig.patch.set_facecolor('#21252b') 

fig.suptitle('Gráficos multiples', fontsize=15, color='w', weight=1000)

# First chart
plt.subplot(2,2,1)
plt.plot(X,y, label='label 1')

plt.title('Primer gráfico', color='w')
plt.xlabel('Eje X', color='w')
plt.ylabel('Eje Y', color='w')

plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

# Second chart
plt.subplot(2,2,2)
plt.scatter(X,y, label='label 2.1')
plt.scatter(y,X, label='label 2.2')

plt.title('Segundo gráfico', color='w')
plt.xlabel('Eje X', color='w')
plt.ylabel('Eje Y', color='w')

plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

# Third chart
plt.subplot(2,2,3)
plt.scatter(X,y, label='label 3')

plt.title('Tercer gráfico', color='w')
plt.xlabel('Eje X', color='w')
plt.ylabel('Eje Y', color='w')

plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

# Fourth chart
plt.subplot(2,2,4)
plt.plot(X,y, label='label 4.1')
plt.plot(y,X, label='label 4.2')

plt.title('Cuarto gráfico', color='w')
plt.xlabel('Eje X', color='w')
plt.ylabel('Eje Y', color='w')

plt.xticks(fontsize=10, color='w', weight=500)
plt.yticks(fontsize=10, color='w', weight=500)

for i in range(2):
    for j in range(2):
        ax[i,j].set_facecolor('#282c34') 
        ax[i,j].grid(linewidth=0.2)
        ax[i,j].legend()

ax[0,1].legend(bbox_to_anchor=(1.25,0.9))
        
fig.tight_layout()
plt.show()

# %% [markdown]
# #### **Gráficos en el mismo lienzo**

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes2 = fig.add_axes([0.2, 0.6, 0.4, 0.3])

axes.plot(X, y, 'r')
axes2.plot(y, X, 'b')

plt.show()

# %% [markdown]
# #### **Diferentes estilos**

# %%
for i in plt.style.available:
    fig, ax = plt.subplots(figsize=(10, 4))

    plt.style.use(i)
    plt.plot(X, y)
    plt.title(f'Gráfico con estilo {i}')
    print('\n')

    plt.show()

# %% [markdown]
# ### **Tipos de gráficos**

# %% [markdown]
# #### **Barplot**

# %%
country = ['Colombia', 'India', 'Japon', 'Mexico', 'Alemania']
population = [1000, 800, 900, 1000, 300]

# %%
fig, ax = plt.subplots(figsize=(14, 5))
fig.patch.set_facecolor('#21252b') 

plt.suptitle('Barplot', fontsize= 18, color='white')

plt.bar(country, population, width=0.6) 

ax.set_facecolor('#282c34') 
plt.xticks(fontsize=13, color='w', weight=500, rotation=45)
plt.yticks(fontsize=13, color='w', weight=500)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 5))
fig.patch.set_facecolor('#21252b') 

plt.suptitle('Barplot', fontsize= 18, color='white')

plt.barh(country, population, height=0.6) 

ax.set_facecolor('#282c34') 
plt.xticks(fontsize=13, color='w', weight=500)
plt.yticks(fontsize=13, color='w', weight=500)

plt.show()
